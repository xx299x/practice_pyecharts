# %%
import jieba
import jieba.analyse
import pyecharts.options as opts
from pyecharts.charts import WordCloud
from collections import Counter

# %%
with open('text.txt','r',encoding='utf-8') as f:
    text = f.read()
    word_list=jieba.analyse.extract_tags(text, topK=100, withWeight=True, allowPOS=())
    # sentence:待提取的文本。
    # topK:返回几个 TF/IDF 权重最大的关键词，默认值为20。
    # withWeight:是否一并返回关键词权重值，默认值为False。
    # allowPOS:仅包括指定词性的词，默认值为空，即不进行筛选。

# %%
(
    WordCloud()
    #资源名改为自己分词好的word_list。
    .add(series_name="热点分析", 
         data_pair=word_list, 
         word_size_range=[6, 66], 
         shape='diamond')
    
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="热点分析", title_textstyle_opts=opts.TextStyleOpts(font_size=25)
        ),
        tooltip_opts=opts.TooltipOpts(is_show=True),
    )
    .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="b36dafb1e1d340ee8d0f0a5009b998c3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_b36dafb1e1d340ee8d0f0a5009b998c3 = echarts.init(
#                     document.getElementById('b36dafb1e1d340ee8d0f0a5009b998c3'), 'white', {renderer: 'canvas'});
#                 var option_b36dafb1e1d340ee8d0f0a5009b998c3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "name": "\u70ed\u70b9\u5206\u6790",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 66
#             ],
#             "data": [
#                 {
#                     "name": "\u6211\u4eec",
#                     "value": 0.17330667075095504,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(93,142,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd9\u4e2a",
#                     "value": 0.09787480913658407,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,19,34)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u5982\u8bf4",
#                     "value": 0.05920621894866518,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(115,29,121)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u89c9\u5f97",
#                     "value": 0.05731043619632784,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,14,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u95ee\u9898",
#                     "value": 0.04371929241459369,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,18,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u4e2a",
#                     "value": 0.03934028165498464,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,66,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6240\u4ee5",
#                     "value": 0.03899940874845574,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,31,122)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd9\u6837",
#                     "value": 0.03745129784114773,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,71,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73b0\u5728",
#                     "value": 0.033674755660094945,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(149,27,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u54a8\u8be2",
#                     "value": 0.03356772113842502,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(120,10,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ec0\u4e48",
#                     "value": 0.03311910127650795,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(83,57,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8f83",
#                     "value": 0.03131428666558224,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,131,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b9e\u9645\u4e0a",
#                     "value": 0.03023310271967118,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(148,150,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7136\u540e",
#                     "value": 0.02919833114267174,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,49,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u6837",
#                     "value": 0.029055662982718517,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,146,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65f6\u5019",
#                     "value": 0.028743343200938284,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(124,128,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f01\u4e1a",
#                     "value": 0.02799974571141092,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,95,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53ef\u80fd",
#                     "value": 0.027736035080101928,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(121,53,130)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9879\u76ee",
#                     "value": 0.027270764546886345,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,52,50)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5c31\u662f",
#                     "value": 0.02662712827565205,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,44,48)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u91cc\u9762",
#                     "value": 0.025776169078651216,
